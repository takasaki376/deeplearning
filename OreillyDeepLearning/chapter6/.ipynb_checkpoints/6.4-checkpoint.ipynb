# %% [markdown]
# ## 6.4.1 過学習
#
# 過学習が起きる原因として、主に次の２つが挙げられます。
# - パラメータを大量に持ち、表現力の高いモデルであること
# - 訓練データが少ないこと

# %% [markdown]
# わざと過学習を発生させます。
#
# ch06\batch_norm_gradient_check.py \
# `weight_decay_lambda = 0`を指定します

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（荷重減衰）の設定 =======================
weight_decay_lambda = 0 # weight decayを使用しない場合
#weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.13, test acc:0.1084
# epoch:1, train acc:0.17333333333333334, test acc:0.1425
# epoch:2, train acc:0.22666666666666666, test acc:0.1769
# epoch:3, train acc:0.23333333333333334, test acc:0.1864
# epoch:4, train acc:0.24666666666666667, test acc:0.1982
# epoch:5, train acc:0.24666666666666667, test acc:0.2002
# epoch:6, train acc:0.29333333333333333, test acc:0.2214
# epoch:7, train acc:0.31, test acc:0.2335
# epoch:8, train acc:0.3233333333333333, test acc:0.2375
# epoch:9, train acc:0.35, test acc:0.248
# epoch:10, train acc:0.35, test acc:0.2558
# epoch:11, train acc:0.37333333333333335, test acc:0.2636
# epoch:12, train acc:0.39666666666666667, test acc:0.2834
# epoch:13, train acc:0.44666666666666666, test acc:0.3021
# epoch:14, train acc:0.44333333333333336, test acc:0.3144
# epoch:15, train acc:0.48, test acc:0.3319
# epoch:16, train acc:0.52, test acc:0.3597
# epoch:17, train acc:0.5533333333333333, test acc:0.3701
# epoch:18, train acc:0.5733333333333334, test acc:0.3906
# epoch:19, train acc:0.59, test acc:0.3966
# epoch:20, train acc:0.5733333333333334, test acc:0.3952
# epoch:21, train acc:0.6366666666666667, test acc:0.4386
# epoch:22, train acc:0.6533333333333333, test acc:0.4624
# epoch:23, train acc:0.67, test acc:0.4735
# epoch:24, train acc:0.67, test acc:0.482
# epoch:25, train acc:0.6966666666666667, test acc:0.4882
# epoch:26, train acc:0.73, test acc:0.5028
# epoch:27, train acc:0.7166666666666667, test acc:0.5189
# epoch:28, train acc:0.7466666666666667, test acc:0.5254
# epoch:29, train acc:0.7466666666666667, test acc:0.538
# epoch:30, train acc:0.7533333333333333, test acc:0.5446
# epoch:31, train acc:0.7833333333333333, test acc:0.5626
# epoch:32, train acc:0.7733333333333333, test acc:0.5673
# epoch:33, train acc:0.8233333333333334, test acc:0.5869
# epoch:34, train acc:0.8133333333333334, test acc:0.5888
# epoch:35, train acc:0.82, test acc:0.5994
# epoch:36, train acc:0.8366666666666667, test acc:0.6026
# epoch:37, train acc:0.8233333333333334, test acc:0.6121
# epoch:38, train acc:0.8466666666666667, test acc:0.6186
# epoch:39, train acc:0.86, test acc:0.6303
# epoch:40, train acc:0.8566666666666667, test acc:0.6298
# epoch:41, train acc:0.8666666666666667, test acc:0.6425
# epoch:42, train acc:0.8766666666666667, test acc:0.6395
# epoch:43, train acc:0.87, test acc:0.6547
# epoch:44, train acc:0.88, test acc:0.6505
# epoch:45, train acc:0.8733333333333333, test acc:0.6427
# epoch:46, train acc:0.8833333333333333, test acc:0.6598
# epoch:47, train acc:0.8933333333333333, test acc:0.673
# epoch:48, train acc:0.8866666666666667, test acc:0.6699
# epoch:49, train acc:0.9066666666666666, test acc:0.6695
# epoch:50, train acc:0.9, test acc:0.6768
# epoch:51, train acc:0.9033333333333333, test acc:0.6802
# epoch:52, train acc:0.8966666666666666, test acc:0.6869
# epoch:53, train acc:0.91, test acc:0.6676
# epoch:54, train acc:0.9133333333333333, test acc:0.6851
# epoch:55, train acc:0.92, test acc:0.6848
# epoch:56, train acc:0.93, test acc:0.6903
# epoch:57, train acc:0.9266666666666666, test acc:0.6799
# epoch:58, train acc:0.9333333333333333, test acc:0.6929
# epoch:59, train acc:0.9333333333333333, test acc:0.6965
# epoch:60, train acc:0.9366666666666666, test acc:0.69
# epoch:61, train acc:0.93, test acc:0.6984
# epoch:62, train acc:0.9366666666666666, test acc:0.7057
# epoch:63, train acc:0.9466666666666667, test acc:0.7018
# epoch:64, train acc:0.94, test acc:0.7035
# epoch:65, train acc:0.9433333333333334, test acc:0.7113
# epoch:66, train acc:0.9466666666666667, test acc:0.7055
# epoch:67, train acc:0.9566666666666667, test acc:0.7034
# epoch:68, train acc:0.9466666666666667, test acc:0.6984
# epoch:69, train acc:0.9533333333333334, test acc:0.7117
# epoch:70, train acc:0.9566666666666667, test acc:0.7134
# epoch:71, train acc:0.9566666666666667, test acc:0.7108
# epoch:72, train acc:0.96, test acc:0.7152
# epoch:73, train acc:0.9566666666666667, test acc:0.7089
# epoch:74, train acc:0.9633333333333334, test acc:0.7133
# epoch:75, train acc:0.97, test acc:0.7189
# epoch:76, train acc:0.97, test acc:0.7176
# epoch:77, train acc:0.97, test acc:0.7137
# epoch:78, train acc:0.9733333333333334, test acc:0.7215
# epoch:79, train acc:0.9666666666666667, test acc:0.7197
# epoch:80, train acc:0.97, test acc:0.7162
# epoch:81, train acc:0.9766666666666667, test acc:0.7233
# epoch:82, train acc:0.9766666666666667, test acc:0.7215
# epoch:83, train acc:0.9733333333333334, test acc:0.7231
# epoch:84, train acc:0.9766666666666667, test acc:0.7226
# epoch:85, train acc:0.9766666666666667, test acc:0.7229
# epoch:86, train acc:0.98, test acc:0.7202
# epoch:87, train acc:0.9833333333333333, test acc:0.7289
# epoch:88, train acc:0.98, test acc:0.7232
# epoch:89, train acc:0.9833333333333333, test acc:0.7276
# epoch:90, train acc:0.9866666666666667, test acc:0.7272
# epoch:91, train acc:0.99, test acc:0.7281
# epoch:92, train acc:0.9866666666666667, test acc:0.726
# epoch:93, train acc:0.9866666666666667, test acc:0.7275
# epoch:94, train acc:0.99, test acc:0.729
# epoch:95, train acc:0.99, test acc:0.7285
# epoch:96, train acc:0.9966666666666667, test acc:0.7272
# epoch:97, train acc:0.9933333333333333, test acc:0.7286
# epoch:98, train acc:0.9933333333333333, test acc:0.7321
# epoch:99, train acc:0.9966666666666667, test acc:0.7323
# epoch:100, train acc:0.9966666666666667, test acc:0.7308
# epoch:101, train acc:0.9933333333333333, test acc:0.7319
# epoch:102, train acc:0.9966666666666667, test acc:0.7342
# epoch:103, train acc:0.9966666666666667, test acc:0.7352
# epoch:104, train acc:0.9966666666666667, test acc:0.7356
# epoch:105, train acc:0.9966666666666667, test acc:0.7298
# epoch:106, train acc:1.0, test acc:0.7308
# epoch:107, train acc:1.0, test acc:0.7329
# epoch:108, train acc:0.9966666666666667, test acc:0.7383
# epoch:109, train acc:0.9966666666666667, test acc:0.7367
# epoch:110, train acc:1.0, test acc:0.7335
# epoch:111, train acc:0.9966666666666667, test acc:0.7388
# epoch:112, train acc:1.0, test acc:0.7362
# epoch:113, train acc:0.9966666666666667, test acc:0.7405
# epoch:114, train acc:1.0, test acc:0.7354
# epoch:115, train acc:1.0, test acc:0.7376
# epoch:116, train acc:1.0, test acc:0.7387
# epoch:117, train acc:0.9966666666666667, test acc:0.7409
# epoch:118, train acc:1.0, test acc:0.7376
# epoch:119, train acc:1.0, test acc:0.7401
# epoch:120, train acc:1.0, test acc:0.737
# epoch:121, train acc:1.0, test acc:0.74
# epoch:122, train acc:1.0, test acc:0.7407
# epoch:123, train acc:1.0, test acc:0.7393
# epoch:124, train acc:1.0, test acc:0.7375
# epoch:125, train acc:1.0, test acc:0.7383
# epoch:126, train acc:1.0, test acc:0.7388
# epoch:127, train acc:1.0, test acc:0.7422
# epoch:128, train acc:1.0, test acc:0.7405
# epoch:129, train acc:1.0, test acc:0.7412
# epoch:130, train acc:1.0, test acc:0.7387
# epoch:131, train acc:1.0, test acc:0.7405
# epoch:132, train acc:1.0, test acc:0.7398
# epoch:133, train acc:1.0, test acc:0.7383
# epoch:134, train acc:1.0, test acc:0.7391
# epoch:135, train acc:1.0, test acc:0.7424
# epoch:136, train acc:1.0, test acc:0.7421
# epoch:137, train acc:1.0, test acc:0.74
# epoch:138, train acc:1.0, test acc:0.7421
# epoch:139, train acc:1.0, test acc:0.7411
# epoch:140, train acc:1.0, test acc:0.7424
# epoch:141, train acc:1.0, test acc:0.7428
# epoch:142, train acc:1.0, test acc:0.7438
# epoch:143, train acc:1.0, test acc:0.7432
# epoch:144, train acc:1.0, test acc:0.7448
# epoch:145, train acc:1.0, test acc:0.7436
# epoch:146, train acc:1.0, test acc:0.7451
# epoch:147, train acc:1.0, test acc:0.7442
# epoch:148, train acc:1.0, test acc:0.7438
# epoch:149, train acc:1.0, test acc:0.745
# epoch:150, train acc:1.0, test acc:0.7451
# epoch:151, train acc:1.0, test acc:0.7441
# epoch:152, train acc:1.0, test acc:0.7449
# epoch:153, train acc:1.0, test acc:0.748
# epoch:154, train acc:1.0, test acc:0.745
# epoch:155, train acc:1.0, test acc:0.7466
# epoch:156, train acc:1.0, test acc:0.7459
# epoch:157, train acc:1.0, test acc:0.7457
# epoch:158, train acc:1.0, test acc:0.7459
# epoch:159, train acc:1.0, test acc:0.7469
# epoch:160, train acc:1.0, test acc:0.7451
# epoch:161, train acc:1.0, test acc:0.7457
# epoch:162, train acc:1.0, test acc:0.7478
# epoch:163, train acc:1.0, test acc:0.748
# epoch:164, train acc:1.0, test acc:0.7471
# epoch:165, train acc:1.0, test acc:0.748
# epoch:166, train acc:1.0, test acc:0.748
# epoch:167, train acc:1.0, test acc:0.7481
# epoch:168, train acc:1.0, test acc:0.7465
# epoch:169, train acc:1.0, test acc:0.7473
# epoch:170, train acc:1.0, test acc:0.7499
# epoch:171, train acc:1.0, test acc:0.7506
# epoch:172, train acc:1.0, test acc:0.7506
# epoch:173, train acc:1.0, test acc:0.7494
# epoch:174, train acc:1.0, test acc:0.7496
# epoch:175, train acc:1.0, test acc:0.7517
# epoch:176, train acc:1.0, test acc:0.7519
# epoch:177, train acc:1.0, test acc:0.7515
# epoch:178, train acc:1.0, test acc:0.7499
# epoch:179, train acc:1.0, test acc:0.7515
# epoch:180, train acc:1.0, test acc:0.7512
# epoch:181, train acc:1.0, test acc:0.752
# epoch:182, train acc:1.0, test acc:0.7517
# epoch:183, train acc:1.0, test acc:0.7507
# epoch:184, train acc:1.0, test acc:0.7509
# epoch:185, train acc:1.0, test acc:0.752
# epoch:186, train acc:1.0, test acc:0.751
# epoch:187, train acc:1.0, test acc:0.7507
# epoch:188, train acc:1.0, test acc:0.7518
# epoch:189, train acc:1.0, test acc:0.753
# epoch:190, train acc:1.0, test acc:0.7528
# epoch:191, train acc:1.0, test acc:0.751
# epoch:192, train acc:1.0, test acc:0.7506
# epoch:193, train acc:1.0, test acc:0.7534
# epoch:194, train acc:1.0, test acc:0.7509
# epoch:195, train acc:1.0, test acc:0.7522
# epoch:196, train acc:1.0, test acc:0.7528
# epoch:197, train acc:1.0, test acc:0.7529
# epoch:198, train acc:1.0, test acc:0.7529
# epoch:199, train acc:1.0, test acc:0.753
# epoch:200, train acc:1.0, test acc:0.7534

# %% [markdown]
# ## 6.4.2 Weight decay
#
# 学習の過程において、大きな重みを持つことに対してペナルティを課すことで、過学習を抑制しようというものです。 \
# そもそも過学習は、重みパラメータが大きな値を取ることによって発生することが多くあるのです。

# %% [markdown]
# ch06\batch_norm_gradient_check.py \
# `weight_decay_lambda = 0.1`を指定します。

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（荷重減衰）の設定 =======================
#weight_decay_lambda = 0 # weight decayを使用しない場合
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.09666666666666666, test acc:0.0948
# epoch:1, train acc:0.1, test acc:0.0946
# epoch:2, train acc:0.10333333333333333, test acc:0.0957
# epoch:3, train acc:0.11333333333333333, test acc:0.0969
# epoch:4, train acc:0.11666666666666667, test acc:0.0998
# epoch:5, train acc:0.12, test acc:0.1036
# epoch:6, train acc:0.12666666666666668, test acc:0.1096
# epoch:7, train acc:0.13666666666666666, test acc:0.11
# epoch:8, train acc:0.14333333333333334, test acc:0.1121
# epoch:9, train acc:0.16, test acc:0.119
# epoch:10, train acc:0.17, test acc:0.1235
# epoch:11, train acc:0.19, test acc:0.128
# epoch:12, train acc:0.22333333333333333, test acc:0.1409
# epoch:13, train acc:0.23333333333333334, test acc:0.1486
# epoch:14, train acc:0.24333333333333335, test acc:0.1571
# epoch:15, train acc:0.2633333333333333, test acc:0.1774
# epoch:16, train acc:0.27666666666666667, test acc:0.1916
# epoch:17, train acc:0.3333333333333333, test acc:0.2127
# epoch:18, train acc:0.3233333333333333, test acc:0.2224
# epoch:19, train acc:0.35333333333333333, test acc:0.2501
# epoch:20, train acc:0.36666666666666664, test acc:0.2718
# epoch:21, train acc:0.3933333333333333, test acc:0.2838
# epoch:22, train acc:0.44333333333333336, test acc:0.3131
# epoch:23, train acc:0.43333333333333335, test acc:0.3144
# epoch:24, train acc:0.46, test acc:0.3372
# epoch:25, train acc:0.49333333333333335, test acc:0.3484
# epoch:26, train acc:0.53, test acc:0.3648
# epoch:27, train acc:0.5233333333333333, test acc:0.3761
# epoch:28, train acc:0.5466666666666666, test acc:0.3883
# epoch:29, train acc:0.57, test acc:0.3993
# epoch:30, train acc:0.6033333333333334, test acc:0.4176
# epoch:31, train acc:0.59, test acc:0.4142
# epoch:32, train acc:0.6133333333333333, test acc:0.4284
# epoch:33, train acc:0.6133333333333333, test acc:0.4367
# epoch:34, train acc:0.61, test acc:0.4363
# epoch:35, train acc:0.6233333333333333, test acc:0.457
# epoch:36, train acc:0.6366666666666667, test acc:0.4606
# epoch:37, train acc:0.63, test acc:0.4578
# epoch:38, train acc:0.64, test acc:0.4713
# epoch:39, train acc:0.63, test acc:0.4775
# epoch:40, train acc:0.64, test acc:0.4875
# epoch:41, train acc:0.6466666666666666, test acc:0.4916
# epoch:42, train acc:0.6433333333333333, test acc:0.4944
# epoch:43, train acc:0.6466666666666666, test acc:0.4918
# epoch:44, train acc:0.6533333333333333, test acc:0.4916
# epoch:45, train acc:0.6533333333333333, test acc:0.4965
# epoch:46, train acc:0.6566666666666666, test acc:0.5019
# epoch:47, train acc:0.6666666666666666, test acc:0.5079
# epoch:48, train acc:0.6766666666666666, test acc:0.5133
# epoch:49, train acc:0.6833333333333333, test acc:0.5225
# epoch:50, train acc:0.68, test acc:0.5234
# epoch:51, train acc:0.6866666666666666, test acc:0.5359
# epoch:52, train acc:0.6833333333333333, test acc:0.538
# epoch:53, train acc:0.6866666666666666, test acc:0.5398
# epoch:54, train acc:0.6933333333333334, test acc:0.5494
# epoch:55, train acc:0.6933333333333334, test acc:0.5551
# epoch:56, train acc:0.7, test acc:0.5607
# epoch:57, train acc:0.7066666666666667, test acc:0.5583
# epoch:58, train acc:0.6966666666666667, test acc:0.5606
# epoch:59, train acc:0.6966666666666667, test acc:0.5586
# epoch:60, train acc:0.7033333333333334, test acc:0.5672
# epoch:61, train acc:0.7033333333333334, test acc:0.5712
# epoch:62, train acc:0.6933333333333334, test acc:0.557
# epoch:63, train acc:0.7, test acc:0.5716
# epoch:64, train acc:0.7033333333333334, test acc:0.5655
# epoch:65, train acc:0.7266666666666667, test acc:0.5876
# epoch:66, train acc:0.7333333333333333, test acc:0.5874
# epoch:67, train acc:0.7333333333333333, test acc:0.5943
# epoch:68, train acc:0.7233333333333334, test acc:0.5854
# epoch:69, train acc:0.7233333333333334, test acc:0.5825
# epoch:70, train acc:0.73, test acc:0.5942
# epoch:71, train acc:0.7366666666666667, test acc:0.5895
# epoch:72, train acc:0.7566666666666667, test acc:0.6031
# epoch:73, train acc:0.7333333333333333, test acc:0.5936
# epoch:74, train acc:0.7366666666666667, test acc:0.5992
# epoch:75, train acc:0.73, test acc:0.5946
# epoch:76, train acc:0.7566666666666667, test acc:0.6095
# epoch:77, train acc:0.7833333333333333, test acc:0.6258
# epoch:78, train acc:0.7866666666666666, test acc:0.6184
# epoch:79, train acc:0.79, test acc:0.6207
# epoch:80, train acc:0.8066666666666666, test acc:0.6279
# epoch:81, train acc:0.7766666666666666, test acc:0.6175
# epoch:82, train acc:0.7733333333333333, test acc:0.6175
# epoch:83, train acc:0.7933333333333333, test acc:0.6215
# epoch:84, train acc:0.7966666666666666, test acc:0.628
# epoch:85, train acc:0.79, test acc:0.618
# epoch:86, train acc:0.81, test acc:0.633
# epoch:87, train acc:0.8033333333333333, test acc:0.6422
# epoch:88, train acc:0.8066666666666666, test acc:0.6389
# epoch:89, train acc:0.81, test acc:0.6281
# epoch:90, train acc:0.8266666666666667, test acc:0.6475
# epoch:91, train acc:0.8166666666666667, test acc:0.648
# epoch:92, train acc:0.8233333333333334, test acc:0.6611
# epoch:93, train acc:0.83, test acc:0.6481
# epoch:94, train acc:0.82, test acc:0.6455
# epoch:95, train acc:0.83, test acc:0.6643
# epoch:96, train acc:0.82, test acc:0.6739
# epoch:97, train acc:0.8333333333333334, test acc:0.6663
# epoch:98, train acc:0.8333333333333334, test acc:0.6587
# epoch:99, train acc:0.8266666666666667, test acc:0.6566
# epoch:100, train acc:0.83, test acc:0.6637
# epoch:101, train acc:0.8166666666666667, test acc:0.6447
# epoch:102, train acc:0.8266666666666667, test acc:0.6488
# epoch:103, train acc:0.8333333333333334, test acc:0.6581
# epoch:104, train acc:0.84, test acc:0.6644
# epoch:105, train acc:0.84, test acc:0.658
# epoch:106, train acc:0.83, test acc:0.6636
# epoch:107, train acc:0.8433333333333334, test acc:0.6698
# epoch:108, train acc:0.8333333333333334, test acc:0.6805
# epoch:109, train acc:0.8366666666666667, test acc:0.6704
# epoch:110, train acc:0.84, test acc:0.6685
# epoch:111, train acc:0.8433333333333334, test acc:0.6647
# epoch:112, train acc:0.8466666666666667, test acc:0.6755
# epoch:113, train acc:0.84, test acc:0.6697
# epoch:114, train acc:0.8433333333333334, test acc:0.6714
# epoch:115, train acc:0.85, test acc:0.6813
# epoch:116, train acc:0.8466666666666667, test acc:0.672
# epoch:117, train acc:0.8433333333333334, test acc:0.6785
# epoch:118, train acc:0.8333333333333334, test acc:0.6696
# epoch:119, train acc:0.8566666666666667, test acc:0.6793
# epoch:120, train acc:0.8566666666666667, test acc:0.6831
# epoch:121, train acc:0.8466666666666667, test acc:0.6851
# epoch:122, train acc:0.8433333333333334, test acc:0.6884
# epoch:123, train acc:0.85, test acc:0.6853
# epoch:124, train acc:0.84, test acc:0.6825
# epoch:125, train acc:0.8533333333333334, test acc:0.6853
# epoch:126, train acc:0.8533333333333334, test acc:0.6966
# epoch:127, train acc:0.8466666666666667, test acc:0.6938
# epoch:128, train acc:0.8533333333333334, test acc:0.692
# epoch:129, train acc:0.85, test acc:0.6913
# epoch:130, train acc:0.8433333333333334, test acc:0.6885
# epoch:131, train acc:0.8433333333333334, test acc:0.6921
# epoch:132, train acc:0.8533333333333334, test acc:0.6946
# epoch:133, train acc:0.8533333333333334, test acc:0.6907
# epoch:134, train acc:0.85, test acc:0.6924
# epoch:135, train acc:0.8433333333333334, test acc:0.6949
# epoch:136, train acc:0.8566666666666667, test acc:0.6963
# epoch:137, train acc:0.87, test acc:0.6947
# epoch:138, train acc:0.8566666666666667, test acc:0.6951
# epoch:139, train acc:0.86, test acc:0.6976
# epoch:140, train acc:0.8533333333333334, test acc:0.6908
# epoch:141, train acc:0.8666666666666667, test acc:0.6979
# epoch:142, train acc:0.8733333333333333, test acc:0.7006
# epoch:143, train acc:0.8666666666666667, test acc:0.6982
# epoch:144, train acc:0.8566666666666667, test acc:0.6967
# epoch:145, train acc:0.8566666666666667, test acc:0.6981
# epoch:146, train acc:0.8666666666666667, test acc:0.6939
# epoch:147, train acc:0.8633333333333333, test acc:0.7008
# epoch:148, train acc:0.8633333333333333, test acc:0.7005
# epoch:149, train acc:0.88, test acc:0.7026
# epoch:150, train acc:0.8666666666666667, test acc:0.6996
# epoch:151, train acc:0.8766666666666667, test acc:0.6944
# epoch:152, train acc:0.8533333333333334, test acc:0.6981
# epoch:153, train acc:0.8566666666666667, test acc:0.6979
# epoch:154, train acc:0.87, test acc:0.7061
# epoch:155, train acc:0.86, test acc:0.7024
# epoch:156, train acc:0.86, test acc:0.7024
# epoch:157, train acc:0.87, test acc:0.7034
# epoch:158, train acc:0.88, test acc:0.7027
# epoch:159, train acc:0.8766666666666667, test acc:0.7094
# epoch:160, train acc:0.8666666666666667, test acc:0.704
# epoch:161, train acc:0.8733333333333333, test acc:0.7058
# epoch:162, train acc:0.8766666666666667, test acc:0.7061
# epoch:163, train acc:0.8833333333333333, test acc:0.7093
# epoch:164, train acc:0.8633333333333333, test acc:0.7034
# epoch:165, train acc:0.8833333333333333, test acc:0.7069
# epoch:166, train acc:0.88, test acc:0.7077
# epoch:167, train acc:0.8766666666666667, test acc:0.7103
# epoch:168, train acc:0.8833333333333333, test acc:0.704
# epoch:169, train acc:0.8766666666666667, test acc:0.7101
# epoch:170, train acc:0.8833333333333333, test acc:0.7162
# epoch:171, train acc:0.88, test acc:0.7073
# epoch:172, train acc:0.8866666666666667, test acc:0.7108
# epoch:173, train acc:0.8733333333333333, test acc:0.7101
# epoch:174, train acc:0.8666666666666667, test acc:0.7094
# epoch:175, train acc:0.8766666666666667, test acc:0.7128
# epoch:176, train acc:0.87, test acc:0.7063
# epoch:177, train acc:0.8833333333333333, test acc:0.7144
# epoch:178, train acc:0.89, test acc:0.7176
# epoch:179, train acc:0.8833333333333333, test acc:0.71
# epoch:180, train acc:0.87, test acc:0.7031
# epoch:181, train acc:0.87, test acc:0.7072
# epoch:182, train acc:0.8766666666666667, test acc:0.7159
# epoch:183, train acc:0.8933333333333333, test acc:0.7146
# epoch:184, train acc:0.8866666666666667, test acc:0.7165
# epoch:185, train acc:0.8733333333333333, test acc:0.7072
# epoch:186, train acc:0.89, test acc:0.7163
# epoch:187, train acc:0.86, test acc:0.703
# epoch:188, train acc:0.8766666666666667, test acc:0.7125
# epoch:189, train acc:0.8866666666666667, test acc:0.7128
# epoch:190, train acc:0.88, test acc:0.7123
# epoch:191, train acc:0.88, test acc:0.7113
# epoch:192, train acc:0.8833333333333333, test acc:0.7122
# epoch:193, train acc:0.88, test acc:0.7161
# epoch:194, train acc:0.9, test acc:0.7215
# epoch:195, train acc:0.8933333333333333, test acc:0.7163
# epoch:196, train acc:0.88, test acc:0.7086
# epoch:197, train acc:0.8933333333333333, test acc:0.7167
# epoch:198, train acc:0.8766666666666667, test acc:0.708
# epoch:199, train acc:0.89, test acc:0.7116
# epoch:200, train acc:0.8866666666666667, test acc:0.7133
